# %%
import pandas as pd

# %%
df = pd.read_parquet('data/enderecos_fiscais.parquet')

# %%
df.head()
# Out:
#   cd_identificador cd_setor_fiscal cd_tipo_quadra cd_quadra_fiscal  \
# 0          1957324             027              F              026
# 1          1957325             027              F              026
# 2          1957326             030              F              131
# 3          1957327             018              F              070
# 4          1957328             016              F              102
#
#   cd_condominio cd_tipo_lote cd_lote cd_digito_sql cd_logradouro  \
# 0            00            F    0019             0        048046
# 1            00            F    0020             4        048046
# 2            00            F    0011             7        020583
# 3            00            F    0018             4        031216
# 4            08            F    0000           NaN        186201
#
#     nm_logradouro_completo cd_numero_porta tx_complemento_endereco
# 0          R CESARIO ALVIM             716                     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1681353 entries, 0 to 1681352
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   cd_identificador         1681353 non-null  str
#  1   cd_setor_fiscal          1681353 non-null  str
#  2   cd_tipo_quadra           1681353 non-null  str
#  3   cd_quadra_fiscal         1681353 non-null  str
#  4   cd_condominio            1681353 non-null  str
#  5   cd_tipo_lote             1681353 non-null  str
#  6   cd_lote                  1681353 non-null  str
#  7   cd_digito_sql            1619256 non-null  str
#  8   cd_logradouro            1658374 non-null  str
#  9   nm_logradouro_completo   1658374 non-null  str
#  10  cd_numero_porta          1658374 non-null  str
#  11  tx_complemento_endereco  1227369 non-null  str
# dtypes: str(12)
# memory usage: 251.9 MB

# %%
pd.read_parquet('data/tipos_logradouro_cache.parquet')

# %%
from services.domain.logradouros_match import match_logradouro, LogradouroMatchQuery

# %%
q = LogradouroMatchQuery(texto="avenida paulista")

# %%
result = match_logradouro(q)

# %%
result.codlogs

# %%
result.ignorou_filtro_tipo

# %%
result.logradouros

# %%
result.match_nome.best_match

# %%
result.match_tipo.best_match

# %%
q = LogradouroMatchQuery(texto="rua paulista")

# %%
result = match_logradouro(q)

# %%
result.logradouros

# %%
result.match_nome.best_match

# %%
result.match_nome.cleaned_query

# %%
result.match_nome.matches

# %%
from services.domain.roteamento_busca import rotear_entrada, RoteamentoQuery

# %%
q=RoteamentoQuery(texto="avenida paulista 1000", finished_typing=True)

# %%
rotear_entrada(q)

# %%
q=RoteamentoQuery(texto="001.002", finished_typing=True)

# %%
rotear_entrada(q)
