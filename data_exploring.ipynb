# %%
import pandas as pd

# %%
df = pd.read_parquet('data/nomes_logradouros.parquet')

# %%
df.head()
# Out:
#    codlog cd_tipo_logradouro        nm_logradouro
# 0  000027                  R      COUTO DE CALVAO
# 1  000035                  R             PIROFONE
# 2  000043                  R          ABACATEIROS
# 3  000051                  R  ABADIA DOS DOURADOS
# 4  000060                  R            ABADIANIA

# %%
df.shape
# Out:
# (50690, 3)

# %%
df = pd.read_parquet('data/segmentos_logradouros.parquet')

# %%
df.head()
# Out:
#    codlog cd_identificador cd_numero_inicial_par cd_numero_final_par  \
# 0  000027           222880                     0                  62
# 1  000035           201562                     0                 124
# 2  000043           120796                     0                  78
# 3  000043           120797                    78                  90
# 4  000043           120798                    90                 164
#
#   cd_numero_inicial_impar cd_numero_final_impar
# 0                       1                    63
# 1                       1                   125
# 2                       1                    79
# 3                      79                    91
# 4                      91                   165

# %%
df.shape
# Out:
# (192077, 6)

# %%
df = pd.read_parquet('data/enderecos_fiscais.parquet')

# %%
df.head()
# Out:
#   cd_identificador cd_setor_fiscal cd_tipo_quadra cd_quadra_fiscal  \
# 0          1957324             027              F              026
# 1          1957325             027              F              026
# 2          1957326             030              F              131
# 3          1957327             018              F              070
# 4          1957328             016              F              102
#
#   cd_condominio cd_tipo_lote cd_lote cd_digito_sql cd_logradouro  \
# 0            00            F    0019             0        048046
# 1            00            F    0020             4        048046
# 2            00            F    0011             7        020583
# 3            00            F    0018             4        031216
# 4            08            F    0000           NaN        186201
#
#     nm_logradouro_completo cd_numero_porta tx_complemento_endereco
# 0          R CESARIO ALVIM             716                     NaN
# ...

# %%
df.shape
# Out:
# (1681353, 12)
