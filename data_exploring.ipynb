# %%
import pandas as pd

# %%
df = pd.read_parquet('data/nomes_logradouros.parquet')

# %%
df.head()
# Out:
#    codlog cd_tipo_logradouro        nm_logradouro
# 0  000027                  R      COUTO DE CALVAO
# 1  000035                  R             PIROFONE
# 2  000043                  R          ABACATEIROS
# 3  000051                  R  ABADIA DOS DOURADOS
# 4  000060                  R            ABADIANIA

# %%
df.shape
# Out:
# (50690, 3)

# %%
pd.read_parquet('data/tipos_logradouro_cache.parquet')
# Out:
#             nome_tipo cd_tipo_logradouro
# 0              ACESSO                 AC
# 1               ACESO                 AC
# 2             ACESSSO                 AC
# 3                  AC                 AC
# 4             ALAMEDA                 AL
# ...               ...                ...
# 6246  VJA DE PEDRESTE                 VP
# 6247  VIA DE P3DRESTE                 VP
# 6248  VIA DE PEDRESTR                 VP
# 6249  VIA DE PEDRESFE                 VP
# 6250  VIA DE PEDRESTF                 VP
#
# [6251 rows x 2 columns]

# %%
from services.domain.logradouros_match import match_logradouro, LogradouroMatchQuery

# %%
q = LogradouroMatchQuery(texto="avenida paulista")

# %%
result = match_logradouro(q)

# %%
result.codlogs
# Out:
# ['156566']

# %%
result.ignorou_filtro_tipo
# Out:
# False

# %%
result.logradouros
# Out:
# [LogradouroMatch(codlog='156566', tipo_codigo='AV', nome_logradouro='PAULISTA')]

# %%
result.match_nome.best_match
# Out:
# FuzzyMatchItem(original_string='PAULISTA', cleaned_string='PAULISTA', similarity_score=100.0, rank_position=1)

# %%
result.match_tipo.best_match
# Out:
# FuzzyMatchItem(original_string='AVENIDA', cleaned_string='AVENIDA', similarity_score=100.0, rank_position=1)

# %%
q = LogradouroMatchQuery(texto="rua paulista")

# %%
result = match_logradouro(q)

# %%
result.logradouros
# Out:
# [LogradouroMatch(codlog='156590', tipo_codigo='R', nome_logradouro='PAULISTANIA')]

# %%
result.match_nome.best_match
# Out:
# FuzzyMatchItem(original_string='PAULISTANIA', cleaned_string='PAULISTANIA', similarity_score=94.54545454545456, rank_position=1)

# %%
result.match_nome.cleaned_query
# Out:
# 'PAULISTA'

# %%
result.match_nome.matches
# Out:
# [FuzzyMatchItem(original_string='PAULISTANIA', cleaned_string='PAULISTANIA', similarity_score=94.54545454545456, rank_position=1),
#  FuzzyMatchItem(original_string='PAULISTANOS', cleaned_string='PAULISTANOS', similarity_score=94.54545454545456, rank_position=2),
#  FuzzyMatchItem(original_string='PAULISTINHA', cleaned_string='PAULISTINHA', similarity_score=94.54545454545456, rank_position=3),
#  FuzzyMatchItem(original_string='PAULINA', cleaned_string='PAULINA', similarity_score=92.14285714285715, rank_position=4),
#  FuzzyMatchItem(original_string='PAULINA', cleaned_string='PAULINA', similarity_score=92.14285714285715, rank_position=5)]
